# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
sns.set(rc={"figure.figsize": (8,5)})
#f, ax= plt.subplots(figsize = (10, 8))
# Out:
# Bad key "text.kerning_factor" on line 4 in
# D:\Anaconda\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
os.chdir('D:\Temp')
file_data=pd.read_csv('datasets_894_813759_2019.csv')
file_data18=pd.read_csv('datasets_894_813759_2018.csv')

# %% [markdown]
# What data we got here ?

# %%
file_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
# Overall rank                    156 non-null int64
# Country or region               156 non-null object
# Score                           156 non-null float64
# GDP per capita                  156 non-null float64
# Social support                  156 non-null float64
# Healthy life expectancy         156 non-null float64
# Freedom to make life choices    156 non-null float64
# Generosity                      156 non-null float64
# Perceptions of corruption       156 non-null float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.0+ KB

# %%
file_data.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
file_data.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption
# 151       0.217                      0.411
# ...

# %%
head_country=file_data.head()

tail_country=file_data.tail()

# %%
compare_data=pd.merge(head_country,tail_country,how='outer',on=['Country or region','GDP per capita'])

# %%
compare_data
# Out:
#    Overall rank_x         Country or region  Score_x  GDP per capita  \
# 0             1.0                   Finland    7.769           1.340
# 1             2.0                   Denmark    7.600           1.383
# 2             3.0                    Norway    7.554           1.488
# 3             4.0                   Iceland    7.494           1.380
# 4             5.0               Netherlands    7.488           1.396
# 5             NaN                    Rwanda      NaN           0.359
# 6             NaN                  Tanzania      NaN           0.476
# 7             NaN               Afghanistan      NaN           0.350
# 8             NaN  Central African Republic      NaN           0.026
# 9             NaN               South Sudan      NaN           0.306
#
#    Social support_x  Healthy life expectancy_x  \
# 0             1.587                      0.986
# 1             1.573                      0.996
# 2             1.582                      1.028
# ...

# %% [markdown]
# Hight Country GDP Compare Low Country GDP
# 1.
# 2.

# %%
ax=sns.barplot(x='GDP per capita',y='Country or region',data=compare_data)
#plt.figure(figsize=(18,20))
#sns.set_xticklabels(labels, rotation=-90)
ax.set_xticklabels(ax.get_xticklabels(), rotation=-90)
# Out:
# [Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, ''),
#  Text(0, 0, '')]

# %%
head_sort=head_country.sort_values(by='GDP per capita',ascending=False)
head_sort
ax=sns.barplot(x='Country or region',y='GDP per capita',data=head_sort)

# %%
tail_sort=tail_country.sort_values(by='GDP per capita',ascending=False)
tail_sort
ax=sns.barplot(x='Country or region',y='GDP per capita',data=tail_sort)

# %%
file_data.describe()
happiness_score = pd.DataFrame(file_data["Score"])
data19=happiness_score.describe().round(2)

data19.rename(columns={'Score':'2019'})
# Out:
#          2019
# count  156.00
# mean     5.41
# std      1.11
# min      2.85
# 25%      4.54
# 50%      5.38
# 75%      6.18
# max      7.77

# %%
file_data18.describe()
happiness_score18 = pd.DataFrame(file_data18["Score"])
data18=happiness_score18.describe().round(2)
data18.rename(columns={'Score':'2018'})
# Out:
#          2018
# count  156.00
# mean     5.38
# std      1.12
# min      2.90
# 25%      4.45
# 50%      5.38
# 75%      6.17
# max      7.63

# %%
#des_data=happiness_score.merge(file_data18,right='Score')
#des_data.head([happiness_score18,happiness_score])
des_data=pd.concat([data18,data19],axis=1)

des_data.columns=['2018','2019']
des_data
# Out:
#          2018    2019
# count  156.00  156.00
# mean     5.38    5.41
# std      1.12    1.11
# min      2.90    2.85
# 25%      4.45    4.54
# 50%      5.38    5.38
# 75%      6.17    6.18
# max      7.63    7.77

# %% [markdown]
# mark...............

# %%
matrix_data = file_data.corr() #get correlation for all cols execpt calss since it's catergorical
sns.heatmap(matrix_data,annot=True)

# %% [markdown]
# Mark........................

# %%
sns.pairplot(file_data,vars=["Score","Generosity","Perceptions of corruption","Freedom to make life choices"])

# %%
file_data.plot(kind='scatter',x='GDP per capita', y='Healthy life expectancy',color='red', alpha=1,grid=True)
plt.xlabel('GDP per capita')
plt.ylabel('Healthy life expectancy')
plt.title('GDP vs Health')
plt.show()

# %%
# Data analysis for Hongkong
#2019
Hk2019=file_data.loc[file_data['Country or region']=='Hong Kong']
Hk2019
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 75            76         Hong Kong   5.43           1.438           1.277
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 75                    1.122                          0.44       0.258
#
#     Perceptions of corruption
# 75                      0.287

# %%
#2020
Hk2018=file_data18.loc[file_data18['Country or region']=='Hong Kong']
Hk2018
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 75            76         Hong Kong   5.43           1.405            1.29
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 75                     1.03                         0.524       0.246
#
#     Perceptions of corruption
# 75                      0.291

# %%
#2019 In Asia Compare
Asia2019 = file_data[(file_data['Country or region'].isin(['Hong Kong','Japan','Taiwan','Korea', 'Singapore','China']))]
Asia2019
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 24            25            Taiwan  6.446           1.368           1.430
# 33            34         Singapore  6.262           1.572           1.463
# 57            58             Japan  5.886           1.327           1.419
# 75            76         Hong Kong  5.430           1.438           1.277
# 92            93             China  5.191           1.029           1.125
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 24                    0.914                         0.351       0.242
# 33                    1.141                         0.556       0.271
# 57                    1.088                         0.445       0.069
# 75                    1.122                         0.440       0.258
# 92                    0.893                         0.521       0.058
#
#     Perceptions of corruption
# 24                      0.097
# 33                      0.453
# ...

# %%
Asia2019.sort_values('GDP per capita',ascending=False)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 33            34         Singapore  6.262           1.572           1.463
# 75            76         Hong Kong  5.430           1.438           1.277
# 24            25            Taiwan  6.446           1.368           1.430
# 57            58             Japan  5.886           1.327           1.419
# 92            93             China  5.191           1.029           1.125
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 33                    1.141                         0.556       0.271
# 75                    1.122                         0.440       0.258
# 24                    0.914                         0.351       0.242
# 57                    1.088                         0.445       0.069
# 92                    0.893                         0.521       0.058
#
#     Perceptions of corruption
# 33                      0.453
# 75                      0.287
# ...

# %%
Asia2018 = file_data18[(file_data18['Country or region'].isin(['Hong Kong','Japan','Taiwan','Korea', 'Singapore','China']))]
Asia2018
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 25            26            Taiwan  6.441           1.365           1.436
# 33            34         Singapore  6.343           1.529           1.451
# 53            54             Japan  5.915           1.294           1.462
# 75            76         Hong Kong  5.430           1.405           1.290
# 85            86             China  5.246           0.989           1.142
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 25                    0.857                         0.418       0.151
# 33                    1.008                         0.631       0.261
# 53                    0.988                         0.553       0.079
# 75                    1.030                         0.524       0.246
# 85                    0.799                         0.597       0.029
#
#     Perceptions of corruption
# 25                      0.078
# 33                      0.457
# ...

# %%
Asia2018.sort_values('GDP per capita',ascending=False)
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 33            34         Singapore  6.343           1.529           1.451
# 75            76         Hong Kong  5.430           1.405           1.290
# 25            26            Taiwan  6.441           1.365           1.436
# 53            54             Japan  5.915           1.294           1.462
# 85            86             China  5.246           0.989           1.142
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 33                    1.008                         0.631       0.261
# 75                    1.030                         0.524       0.246
# 25                    0.857                         0.418       0.151
# 53                    0.988                         0.553       0.079
# 85                    0.799                         0.597       0.029
#
#     Perceptions of corruption
# 33                      0.457
# 75                      0.291
# ...

# %%
# compare for Social support & Perceptions of corruption
plt.figure(figsize=(10,8))
sns.kdeplot(Asia2018['GDP per capita'],color='blue')
sns.kdeplot(Asia2019['GDP per capita'],color='red')
plt.title('Health 2018 vs 2019',size=20) 
plt.xlabel('GDP per capita') 
plt.ylabel('Healthy life expectancy') 
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.kdeplot(Asia2018['Healthy life expectancy'],color='blue')
sns.kdeplot(Asia2019['Healthy life expectancy'],color='red')
plt.title('Health 2018 vs 2019',size=20) 
plt.xlabel('compare for Social support') 
plt.ylabel('Perceptions of corruption') 
plt.show()
